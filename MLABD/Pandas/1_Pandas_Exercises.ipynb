# %% [markdown]
# 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 2. Import the dataset chipotle.tsv

# %% [markdown]
# 3. Assign it to a variable called chipo

# %%
chipo = pd.read_csv('chipotle.tsv', sep='\t')

# %% [markdown]
# 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# 5. What is the number of observations in the dataset?

# %%
chipo.shape
# Out:
# (4622, 5)

# %%
chipo.info(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
chipo.describe().T
# Out:
#            count        mean         std  min     25%    50%     75%     max
# order_id  4622.0  927.254868  528.890796  1.0  477.25  926.0  1393.0  1834.0
# quantity  4622.0    1.075725    0.410186  1.0    1.00    1.0     1.0    15.0

# %%
chipo.describe(include = 'object').T
# Out:
#                    count unique           top freq
# item_name           4622     50  Chicken Bowl  726
# choice_description  3376   1043   [Diet Coke]  134
# item_price          4622     78        $8.75   730

# %%
chipo.describe(include = 'all').T
# Out:
#                      count unique           top freq        mean         std  \
# order_id            4622.0    NaN           NaN  NaN  927.254868  528.890796
# quantity            4622.0    NaN           NaN  NaN    1.075725    0.410186
# item_name             4622     50  Chicken Bowl  726         NaN         NaN
# choice_description    3376   1043   [Diet Coke]  134         NaN         NaN
# item_price            4622     78        $8.75   730         NaN         NaN
#
#                     min     25%    50%     75%     max
# order_id            1.0  477.25  926.0  1393.0  1834.0
# quantity            1.0     1.0    1.0     1.0    15.0
# item_name           NaN     NaN    NaN     NaN     NaN
# choice_description  NaN     NaN    NaN     NaN     NaN
# item_price          NaN     NaN    NaN     NaN     NaN

# %% [markdown]
# 6. What is the number of columns in the dataset?

# %%
chipo.shape[1]
# Out:
# 5

# %% [markdown]
# 7. Print the name of all the columns

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# 9. Which was the most-ordered item?

# %%
most_order = chipo[['item_name', 'quantity']].groupby('item_name').sum()

# %%
most_order.sort_values('quantity', ascending = False).head(1)
# Out:
#               quantity
# item_name
# Chicken Bowl       761

# %% [markdown]
# 11. What was the most ordered item in the choice_description column?

# %%
most_order = chipo[['choice_description', 'quantity']].groupby('choice_description').sum()

# %%
most_order.sort_values('quantity', ascending = False).head(1)
# Out:
#                     quantity
# choice_description
# [Diet Coke]              159

# %%
most_order.sort_values('quantity', ascending = False)
# Out:
#                                                     quantity
# choice_description
# [Diet Coke]                                              159
# [Coke]                                                   143
# [Sprite]                                                  89
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...        49
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...        42
# ...                                                      ...
# [[Tomatillo-Red Chili Salsa (Hot), Fresh Tomato...         1
# [[Tomatillo-Red Chili Salsa (Hot), Fresh Tomato...         1
# [[Tomatillo-Red Chili Salsa (Hot), Fresh Tomato...         1
# [[Tomatillo-Red Chili Salsa (Hot), Fresh Tomato...         1
# [[Tomatillo-Red Chili Salsa (Hot), Fresh Tomato...         1
#
# [1043 rows x 1 columns]

# %% [markdown]
# 12. How many items were orderd in total?

# %%
many_items = chipo['quantity'].sum()
many_items
# Out:
# np.int64(4972)

# %%
chipo['item_name'].sum()
# Out:
# 'Chips and Fresh Tomato SalsaIzzeNantucket NectarChips and Tomatillo-Green Chili SalsaChicken BowlChicken BowlSide of ChipsSteak BurritoSteak Soft TacosSteak BurritoChips and GuacamoleChicken Crispy TacosChicken Soft TacosChicken BowlChips and GuacamoleChips and Tomatillo-Green Chili SalsaChicken BurritoChicken BurritoCanned SodaChicken BowlChips and GuacamoleBarbacoa BurritoNantucket NectarChicken BurritoIzzeChips and Fresh Tomato SalsaChicken BowlCarnitas BurritoCanned SodaChicken BurritoChips and Tomatillo-Green Chili SalsaSteak BurritoSide of ChipsCarnitas BowlBottled WaterChicken Soft TacosChicken Soft TacosChips and GuacamoleChips and Tomatillo Green Chili SalsaBarbacoa BowlChipsChips and GuacamoleChicken BowlSteak BurritoChicken Salad BowlChicken BurritoSteak BurritoIzzeSteak BurritoChips and GuacamoleSteak BurritoCanned SodaChicken BurritoCanned SodaSteak BowlChips and Fresh Tomato SalsaBarbacoa Soft TacosVeggie BurritoBarbacoa BowlChipsChips and GuacamoleSteak Soft TacosVegg
# ...

# %% [markdown]
# 13. Turn the item price into a float

# %% [markdown]
# a. Check the item price type

# %%
chipo['item_price'].dtype
# Out:
# dtype('O')

# %% [markdown]
# b. Create a lambda function and change the type of item price

# %%
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x.replace('$', '')))

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
chipo['item_price']
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %% [markdown]
# c. Check the item price type

# %%
chipo['item_price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# 14. How much was the revenue for the period in the dataset?

# %%
revenue = (chipo['quantity'] * chipo['item_price']).sum()

# %%
revenue
# Out:
# np.float64(39237.02)

# %% [markdown]
# 15. How many orders were made in the period?

# %%
num_orders = chipo["order_id"].nunique()
num_orders
# Out:
# 1834

# %% [markdown]
# 16. What is the average revenue amount per order?

# %%
orders_grouped = chipo.groupby("order_id").apply(lambda x: (x["quantity"] * x["item_price"]).sum())
avg_order_value = orders_grouped.mean()
avg_order_value
# Out:
# C:\Users\aorayden\AppData\Local\Temp\ipykernel_18916\3638507491.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   orders_grouped = chipo.groupby("order_id").apply(lambda x: (x["quantity"] * x["item_price"]).sum())
# np.float64(21.39423118865867)

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
# Out:
# 21.394231188658654

# %% [markdown]
# 17. How many different items are sold?

# %%
num_unique_items = chipo["item_name"].nunique()
num_unique_items
# Out:
# 50

# %%
# Out:
# 50

# %% [markdown]
# 18. How many products cost more than $10.00?

# %%
expensive_items = chipo[chipo["item_price"] > 10]["item_name"].nunique()
expensive_items
# Out:
# 31

# %%
# Out:
# 31

# %% [markdown]
# 19. What is the price of each item?

# %%
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 3363                          Chicken Salad        8.49
# 3471                           Veggie Salad        8.49
# 3502                            Steak Salad        8.69
# 3749                    Carnitas Salad Bowl       11.89
# 3750                         Carnitas Salad        8.99
#
# [228 rows x 2 columns]

# %%
unique_prices = chipo.groupby("item_name")["item_price"].max().to_frame()
unique_prices
# Out:
#                                        item_price
# item_name
# 6 Pack Soft Drink                           12.98
# Barbacoa Bowl                               11.75
# Barbacoa Burrito                            11.75
# Barbacoa Crispy Tacos                       18.50
# Barbacoa Salad Bowl                         11.89
# Barbacoa Soft Tacos                         11.75
# Bottled Water                               15.00
# Bowl                                        22.20
# Burrito                                      7.40
# Canned Soda                                  4.36
# Canned Soft Drink                            5.00
# Carnitas Bowl                               35.25
# Carnitas Burrito                            18.50
# Carnitas Crispy Tacos                       17.98
# Carnitas Salad                               8.99
# Carnitas Salad Bowl                         11.89
# Carnitas Soft Tacos                         11.75
# Chicken Bowl                                32.94
# ...

# %%
# Out:
# (50, 1)

# %%
# Out:
#                                        item_price
# item_name
# 6 Pack Soft Drink                           12.98
# Barbacoa Bowl                               11.75
# Barbacoa Burrito                            11.75
# Barbacoa Crispy Tacos                       18.50
# Barbacoa Salad Bowl                         11.89
# Barbacoa Soft Tacos                         11.75
# Bottled Water                               15.00
# Bowl                                        22.20
# Burrito                                      7.40
# Canned Soda                                  4.36
# Canned Soft Drink                            5.00
# Carnitas Bowl                               35.25
# Carnitas Burrito                            18.50
# Carnitas Crispy Tacos                       17.98
# Carnitas Salad                               8.99
# Carnitas Salad Bowl                         11.89
# Carnitas Soft Tacos                         11.75
# Chicken Bowl                                32.94
# ...

# %% [markdown]
# 20. Sort by the name of the item

# %%
sorted_items = chipo.sort_values("item_name")["item_name"]
sorted_items
# Out:
# 3389    6 Pack Soft Drink
# 341     6 Pack Soft Drink
# 1849    6 Pack Soft Drink
# 1860    6 Pack Soft Drink
# 2713    6 Pack Soft Drink
#               ...
# 2384    Veggie Soft Tacos
# 781     Veggie Soft Tacos
# 2851    Veggie Soft Tacos
# 1699    Veggie Soft Tacos
# 1395    Veggie Soft Tacos
# Name: item_name, Length: 4622, dtype: object

# %% [markdown]
# 21. What was the quantity of the most expensive item ordered?

# %%
most_expensive = chipo.sort_values("item_price", ascending=False).iloc[0]
print(most_expensive)
# Out:
# order_id                                      1443
# quantity                                        15
# item_name             Chips and Fresh Tomato Salsa
# choice_description                             NaN
# item_price                                   44.25
# Name: 3598, dtype: object

# %% [markdown]
# 22. How many times was a Veggie Salad Bowl ordered?

# %%
veggie_salad_count = chipo[chipo["item_name"] == "Veggie Salad Bowl"].shape[0]
veggie_salad_count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 veggie_salad_count = chipo[chipo["item_name"] == "Veggie Salad Bowl"].shape[0]
#       2 veggie_salad_count
#
# NameError: name 'chipo' is not defined

# %% [markdown]
# 23. How many times did someone order more than one Canned Soda?

# %%
multiple_canned_soda = chipo[(chipo["item_name"] == "Canned Soda") & (chipo["quantity"] > 1)].shape[0]
multiple_canned_soda
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 multiple_canned_soda = chipo[(chipo["item_name"] == "Canned Soda") & (chipo["quantity"] > 1)].shape[0]
#       2 multiple_canned_soda
#
# NameError: name 'chipo' is not defined

# %% [markdown]
# ###
