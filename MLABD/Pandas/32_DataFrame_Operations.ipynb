# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Вычисление статистических показателей

# %%
df = pd.DataFrame(np.random.randint(1, 101, 35).reshape(7, 5), ['a', 'b', 'c', 'd', 'e', 'f', 'g'], 
                  ['France', 'Spain', 'Italy', 'Germany', 'Great Britain'])

# %%
df
# Out:
#    France  Spain  Italy  Germany  Great Britain
# a      58     76     17       54              2
# b      35     50     38       75             15
# c      57     27     83       15             19
# d      57     44     30       77             63
# e      39     17      7       24             39
# f      44     57     96        1             98
# g      58     61     32       69             29

# %%
df['France'].max()
# Out:
# 58

# %%
df['France'].min()
# Out:
# 35

# %%
df['France'].sum()
# Out:
# 348

# %%
df['France'].mean()
# Out:
# 49.714285714285715

# %%
df['France'].count()
# Out:
# 7

# %%
df.max()
# Out:
# France           58
# Spain            76
# Italy            96
# Germany          77
# Great Britain    98
# dtype: int32

# %%
df.describe()
# Out:
#           France      Spain      Italy    Germany  Great Britain
# count   7.000000   7.000000   7.000000   7.000000       7.000000
# mean   49.714286  47.428571  43.285714  45.000000      37.857143
# std    10.061714  20.222571  33.405161  31.246333      32.895940
# min    35.000000  17.000000   7.000000   1.000000       2.000000
# 25%    41.500000  35.500000  23.500000  19.500000      17.000000
# 50%    57.000000  50.000000  32.000000  54.000000      29.000000
# 75%    57.500000  59.000000  60.500000  72.000000      51.000000
# max    58.000000  76.000000  96.000000  77.000000      98.000000

# %%
df.describe().T
# Out:
#                count       mean        std   min   25%   50%   75%   max
# France           7.0  49.714286  10.061714  35.0  41.5  57.0  57.5  58.0
# Spain            7.0  47.428571  20.222571  17.0  35.5  50.0  59.0  76.0
# Italy            7.0  43.285714  33.405161   7.0  23.5  32.0  60.5  96.0
# Germany          7.0  45.000000  31.246333   1.0  19.5  54.0  72.0  77.0
# Great Britain    7.0  37.857143  32.895940   2.0  17.0  29.0  51.0  98.0

# %% [markdown]
# #### Нахождение уникальных значений

# %%
df.loc['a','France'] = 57

# %%
df
# Out:
#    France  Spain  Italy  Germany  Great Britain
# a      57     76     17       54              2
# b      35     50     38       75             15
# c      57     27     83       15             19
# d      57     44     30       77             63
# e      39     17      7       24             39
# f      44     57     96        1             98
# g      58     61     32       69             29

# %%
df['France'].unique()
# Out:
# array([57, 35, 39, 44, 58])

# %%
# Количество уникальных значений
df['France'].nunique()
# Out:
# 5

# %%
# Показать количества появлений 
df['France'].value_counts()
# Out:
# France
# 57    3
# 35    1
# 39    1
# 44    1
# 58    1
# Name: count, dtype: int64

# %% [markdown]
# #### Отбор пропущенных значений

# %% [markdown]
# В библиотеке pandas для обозначения пропущенных значений используется значение NaN библиотеки NumPy (от англ. Not a Number — не число).

# %%
df.loc['a', 'France'] = np.NaN

# %%
df
# Out:
#    France  Spain  Italy  Germany  Great Britain
# a     NaN     76     17       54              2
# b    35.0     50     38       75             15
# c    57.0     27     83       15             19
# d    57.0     44     30       77             63
# e    39.0     17      7       24             39
# f    44.0     57     96        1             98
# g    58.0     61     32       69             29

# %%
# Выбрать пропущенные значения
df[df['France'].isnull()].head()
# Out:
#    France  Spain  Italy  Germany  Great Britain
# a     NaN     76     17       54              2

# %%
df.dropna()
# Out:
#    France  Spain  Italy  Germany  Great Britain
# b    35.0     50     38       75             15
# c    57.0     27     83       15             19
# d    57.0     44     30       77             63
# e    39.0     17      7       24             39
# f    44.0     57     96        1             98
# g    58.0     61     32       69             29

# %%
df.dropna(axis=1)
# Out:
#    Spain  Italy  Germany  Great Britain
# a     76     17       54              2
# b     50     38       75             15
# c     27     83       15             19
# d     44     30       77             63
# e     17      7       24             39
# f     57     96        1             98
# g     61     32       69             29

# %%
df.fillna(value='Something')
# Out:
#       France  Spain  Italy  Germany  Great Britain
# a  Something     76     17       54              2
# b       35.0     50     38       75             15
# c       57.0     27     83       15             19
# d       57.0     44     30       77             63
# e       39.0     17      7       24             39
# f       44.0     57     96        1             98
# g       58.0     61     32       69             29

# %%
df['France'].fillna(value=df['France'].mean())
# Out:
# a    48.333333
# b    35.000000
# c    57.000000
# d    57.000000
# e    39.000000
# f    44.000000
# g    58.000000
# Name: France, dtype: float64

# %%
df
# Out:
#    France  Spain  Italy  Germany  Great Britain
# a     NaN     76     17       54              2
# b    35.0     50     38       75             15
# c    57.0     27     83       15             19
# d    57.0     44     30       77             63
# e    39.0     17      7       24             39
# f    44.0     57     96        1             98
# g    58.0     61     32       69             29

# %% [markdown]
# ####  Группирование строк по значениям

# %%
dict = {'Company':['COMP1', 'COMP1', 'COMP2', 'COMP2', 'COMP3', 'COMP3'], 'Month':['JAN', 'FEB', 'MAR', 'APR', 'May','JUN'], 
       'Salary':[2000, 1500, 3000, 5000, 2500, 3500]}

# %%
df = pd.DataFrame(dict)

# %%
df
# Out:
#   Company Month  Salary
# 0   COMP1   JAN    2000
# 1   COMP1   FEB    1500
# 2   COMP2   MAR    3000
# 3   COMP2   APR    5000
# 4   COMP3   May    2500
# 5   COMP3   JUN    3500

# %%
df.groupby('Company').agg({'Salary': ['sum'], 'Month':['count']})
# Out:
#         Salary Month
#            sum count
# Company
# COMP1     3500     2
# COMP2     8000     2
# COMP3     6000     2

# %%
df.groupby(by='Company').count()
# Out:
#          Month  Salary
# Company
# COMP1        2       2
# COMP2        2       2
# COMP3        2       2

# %%
groupby_comp = df.groupby('Company')

# %%
groupby_comp.count()
# Out:
#          Month  Salary
# Company
# COMP1        2       2
# COMP2        2       2
# COMP3        2       2

# %%
groupby_comp.sum()
# Out:
#           Month  Salary
# Company
# COMP1    JANFEB    3500
# COMP2    MARAPR    8000
# COMP3    MayJUN    6000

# %%
groupby_comp['Salary'].sum()
# Out:
# Company
# COMP1    3500
# COMP2    8000
# COMP3    6000
# Name: Salary, dtype: int64

# %%
groupby_comp.sum().loc['COMP3']
# Out:
# Month     MayJUN
# Salary      6000
# Name: COMP3, dtype: object

# %%
groupby_comp.count()
# Out:
#          Month  Salary
# Company
# COMP1        2       2
# COMP2        2       2
# COMP3        2       2

# %%
groupby_comp.max()
# Out:
#         Month  Salary
# Company
# COMP1     JAN    2000
# COMP2     MAR    5000
# COMP3     May    3500

# %%
groupby_comp.min()
# Out:
#         Month  Salary
# Company
# COMP1     FEB    1500
# COMP2     APR    3000
# COMP3     JUN    2500

# %%
df.groupby('Company').describe()
# Out:
#         Salary
#          count    mean          std     min     25%     50%     75%     max
# Company
# COMP1      2.0  1750.0   353.553391  1500.0  1625.0  1750.0  1875.0  2000.0
# COMP2      2.0  4000.0  1414.213562  3000.0  3500.0  4000.0  4500.0  5000.0
# COMP3      2.0  3000.0   707.106781  2500.0  2750.0  3000.0  3250.0  3500.0

# %%
comp3 = df.groupby('Company').describe().transpose()['COMP3']

# %%
comp3
# Out:
# Salary  count       2.000000
#         mean     3000.000000
#         std       707.106781
#         min      2500.000000
#         25%      2750.000000
#         50%      3000.000000
#         75%      3250.000000
#         max      3500.000000
# Name: COMP3, dtype: float64

# %% [markdown]
# #### Обход столбца в цикле

# %%
for x in df['Company'].loc[:2]:
    print(x)
# Out:
# COMP1
# COMP1
# COMP2

# %%
df['Company'].loc[:1]
# Out:
# 0    COMP1
# 1    COMP1
# Name: Company, dtype: object

# %% [markdown]
# #### Применение функции ко всем элементам в столбце

# %% [markdown]
# Для применения встроенной или заданной пользователем функции к каждому элементу в столбце использовать метод apply.

# %%
def times3(x):
    return x * 3

# %%
df['Salary'].apply(times3)
# Out:
# 0     6000
# 1     4500
# 2     9000
# 3    15000
# 4     7500
# 5    10500
# Name: Salary, dtype: int64

# %%
df['Salary'].apply(times3).sum()
# Out:
# 52500

# %%
df['Salary'].apply(lambda x: x * 3)
# Out:
# 0     6000
# 1     4500
# 2     9000
# 3    15000
# 4     7500
# 5    10500
# Name: Salary, dtype: int64

# %%
# Сгруппировать строки, применить функцию к группам 
df.groupby('Company').apply(lambda x : x.count())
# Out:
# C:\Users\МОиБД\AppData\Local\Temp\ipykernel_8016\2986465745.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('Company').apply(lambda x : x.count())
#          Company  Month  Salary
# Company
# COMP1          2      2       2
# COMP2          2      2       2
# COMP3          2      2       2

# %%
df.groupby('Company')[['Month', 'Salary']].apply(lambda x : x.count())
# Out:
#          Month  Salary
# Company
# COMP1        2       2
# COMP2        2       2
# COMP3        2       2

# %% [markdown]
# #### Конкатенация фреймов данныx

# %%
# Создать фрейм данных
data_a = {'id': ['1', '2', '3'], 'first': ['Alex', 'Amy', 'Allen'], 'last': ['Anderson', 'Ackerman', 'Ali']} 
df_a = pd.DataFrame(data_a, columns = ['id', 'first', 'last'])

# %%
# Создать фрейм данных
data_b = {'id': ['4', '5', '6'], 'first': ['Billy', 'Brian', 'Bran'], 'last': ['Bonder', 'Black', 'Balwner']} 
df_b = pd.DataFrame(data_b, columns = ['id', 'first', 'last'])

# %%
df_a
# Out:
#   id  first      last
# 0  1   Alex  Anderson
# 1  2    Amy  Ackerman
# 2  3  Allen       Ali

# %%
df_b
# Out:
#   id  first     last
# 0  4  Billy   Bonder
# 1  5  Brian    Black
# 2  6   Bran  Balwner

# %%
# Конкатенировать фреймы данных по строкам 
pd.concat([df_a, df_b], axis=0)
# Out:
#   id  first      last
# 0  1   Alex  Anderson
# 1  2    Amy  Ackerman
# 2  3  Allen       Ali
# 0  4  Billy    Bonder
# 1  5  Brian     Black
# 2  6   Bran   Balwner

# %%
# Конкатенировать фреймы данных по столбцам 
pd.concat([df_a, df_b], axis=1)
# Out:
#   id  first      last id  first     last
# 0  1   Alex  Anderson  4  Billy   Bonder
# 1  2    Amy  Ackerman  5  Brian    Black
# 2  3  Allen       Ali  6   Bran  Balwner

# %% [markdown]
# ####  Слияние фреймов данных

# %% [markdown]
# Для того чтобы применить внутреннее соединение, использовать метод merge с параметром on, задающим столбец, по которому происходит слияние

# %%
# Создать фрейм данных
employee_data = {'employee_id': ['1', ' 2', '3', '4'], 'name': ['Amy Jones', 'Allen Keys', 'Alice Bees','Tim Horton']}
dataframe_employees = pd.DataFrame(employee_data, columns = ['employee_id', 'name'])

# %%
dataframe_employees
# Out:
#   employee_id        name
# 0           1   Amy Jones
# 1           2  Allen Keys
# 2           3  Alice Bees
# 3           4  Tim Horton

# %%
# Создать фрейм данных
sales_data = {'employee_id': ['3', '4', '5', '6'], 'total_sales':[23456, 2512, 2345, 1455]}
dataframe_sales = pd.DataFrame(sales_data, columns = ['employee_id','total_sales'])

# %%
dataframe_sales
# Out:
#   employee_id  total_sales
# 0           3        23456
# 1           4         2512
# 2           5         2345
# 3           6         1455

# %%
# Выполнить слияние фреймов данных
pd.merge(dataframe_employees, dataframe_sales, on='employee_id')
# Out:
#   employee_id        name  total_sales
# 0           3  Alice Bees        23456
# 1           4  Tim Horton         2512

# %% [markdown]
# Метод merge по умолчанию выполняет операцию внутреннего соединения. Если необходимо сделать внешнее соединение, можно указать это при помощи параметра how

# %%
# Выполнить слияние фреймов данных 
pd.merge(dataframe_employees, dataframe_sales, on='employee_id', how='outer')
# Out:
#   employee_id        name  total_sales
# 0           2  Allen Keys          NaN
# 1           1   Amy Jones          NaN
# 2           3  Alice Bees      23456.0
# 3           4  Tim Horton       2512.0
# 4           5         NaN       2345.0
# 5           6         NaN       1455.0

# %% [markdown]
# Этот же параметр можно использовать для указания левого и правого соединений

# %%
# Выполнить слияние фреймов данных 
pd.merge(dataframe_employees, dataframe_sales, on='employee_id', how='left')
# Out:
#   employee_id        name  total_sales
# 0           1   Amy Jones          NaN
# 1           2  Allen Keys          NaN
# 2           3  Alice Bees      23456.0
# 3           4  Tim Horton       2512.0

# %%
# Выполнить слияние фреймов данных 
pd.merge(dataframe_employees, dataframe_sales, left_on='employee_id', right_on='employee_id')
# Out:
#   employee_id        name  total_sales
# 0           3  Alice Bees        23456
# 1           4  Tim Horton         2512

# %% [markdown]
# Метод merge поддерживает четыре основных типа соединений:
#
# ♦ внутреннее — вернуть только те строки, которые совпадают в обоих фреймах (например, вернуть любую строку, в которой значение employee id появляется одновременно В dataframe_employees И В dataframe_sales);
#
# ♦ внешнее— вернуть все строки в обоих фреймах; если строка существует в одном фрейме, но отсутствует в другом, то пропущенные значения заполнить значениями NaN (например, вернуть все строки И В employee_id, И В dataframe_sales);
#
# ♦ левое — вернуть все строки из левого фрейма, но только те строки из правого фрейма, которые совпали с левым фреймом; пропущенные значения заполнить значениями NaN (например, вернуть все строки ИЗ dataframe_employees, но только те строки из dataframe saies, которые имеют значение для employee id, появляющееся В dataframe_employees);
#
# ♦ правое — вернуть все строки из правого фрейма, но только те строки из левого фрейма, которые совпали с правым фреймом; пропущенные значения заполнить значениями NaN (например, вернуть все строки из dataframe saies, но только те
# строки из dataframe_empioyees, которые имеют значение для empioyee_id, появляющееся В dataframe_sales).

# %%
df1 = pd.DataFrame({
                     'user_name': ['James Brown', 'Jack White',
                                   'Jane Green'],
                     'country': ['USA', 'USA', 
                                    'France']},
                  index=['ind1', 'ind2', 'ind3'])

df2 = pd.DataFrame({'order_id': [114, 235, 432],
                     'user_id': [2, 4, 3],
                     'order_date': ['2020-02-11', '2020-02-11', 
                                    '2020-02-15'],
                     'OS': ['Android', 'iOS', 'Android']},
                    index=['ind1', 'ind4', 'ind3'])

# %%
df1
# Out:
#         user_name country
# ind1  James Brown     USA
# ind2   Jack White     USA
# ind3   Jane Green  France

# %%
df2
# Out:
#       order_id  user_id  order_date       OS
# ind1       114        2  2020-02-11  Android
# ind4       235        4  2020-02-11      iOS
# ind3       432        3  2020-02-15  Android

# %%
df1.join(df2)
# Out:
#         user_name country  order_id  user_id  order_date       OS
# ind1  James Brown     USA     114.0      2.0  2020-02-11  Android
# ind2   Jack White     USA       NaN      NaN         NaN      NaN
# ind3   Jane Green  France     432.0      3.0  2020-02-15  Android

# %%
df2
# Out:
#       order_id  user_id  order_date       OS
# ind1       114        2  2020-02-11  Android
# ind4       235        4  2020-02-11      iOS
# ind3       432        3  2020-02-15  Android

# %%
df2.join(df1)
# Out:
#       order_id  user_id  order_date       OS    user_name country
# ind1       114        2  2020-02-11  Android  James Brown     USA
# ind4       235        4  2020-02-11      iOS          NaN     NaN
# ind3       432        3  2020-02-15  Android   Jane Green  France
